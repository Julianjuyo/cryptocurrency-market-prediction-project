# %%
import pandas as pd
import requests
import json

PROXIES = {
    
   'http': 'http://discproxy.virtual.uniandes.edu.co:443',
}

base_url = "http://172.24.100.128:5000/"
# base_url = "http://localhost:5000/"

# %%
# Method to make a POST request to the specified API endpoint with a JSON payload
def post_method(url_path, data_dict):
    print("POST request to: " + url_path)
    # Convert the dictionary to a JSON string using the `json` module
    json_payload = json.dumps(data_dict)

    print(json_payload)
    # try:
    # Send the POST request with the JSON payload
    response = requests.post(url_path, data=json_payload, proxies=PROXIES)

    # Check if the request was successful
    if response.status_code == requests.codes.created:
        # If successful, print the response content and convert it to a Pandas DataFrame
        print("created post status code: " + str(response.status_code))

        print(response.content)
        json_data = json.loads(response.content)
        df = pd.json_normalize(json_data)
        return df
    else:
        # If unsuccessful, print the response content
        print("post status code: "+str(response.status_code))
        print(response.content)

def create_exchange(base_url, data_dict):
    # Call the `post_mBTCod` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "exchanges")
    resp = post_method(base_url + "exchanges", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)
    
def create_asset(base_url,exchange_id, data_dict):
    # Call the `post_method` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "assets")
    resp = post_method(base_url + "exchanges/"+exchange_id+"/asset", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)

# %%
data ={
    "name": "binance"
}

exchange = create_exchange(base_url,data)


EXCHANGE_ID = exchange.iloc[0]['id']
# Out:
# Endpoint: http://172.24.100.128:5000/exchanges
# POST request to: http://172.24.100.128:5000/exchanges
# {"name": "binance"}
# created post status code: 201
# b'{"id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"name":"binance","created_at":"2023-04-24T05:22:23.693470+00:00"}'

# %%
array=[
    
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  },

  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  },

  {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  }
]


for dict in array:
  create_asset(base_url,EXCHANGE_ID,dict)
# Out:
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","created_at":"2023-04-24T05:22:31.806468+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"day","symbol":"BTCUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"09fbb028-81c2-48dd-9077-d604f8ae856e"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","created_at":"2023-04-24T05:22:31.897495+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"hour","symbol":"BTCUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"2649f871-631a-42cd-bb1a-f199f069daa9"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","created_at":"2023-04-24T05:22:31.980155+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"minute","symbol":"BTCUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"bbf9f332-a499-4473-8095-9c17923556f6"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","created_at":"2023-04-24T05:22:32.069207+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"day","symbol":"BNBUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"d2ef1f0c-8842-4c75-8dc1-61e5410e511b"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","created_at":"2023-04-24T05:22:32.149908+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"hour","symbol":"BNBUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"133d649a-06cb-43bf-960f-f3f5fa638af1"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","created_at":"2023-04-24T05:22:32.229724+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"minute","symbol":"BNBUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"9a5e2374-d3b7-4408-9860-7a8fa34ac27e"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","created_at":"2023-04-24T05:22:32.308602+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"day","symbol":"ETHUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"9d14a067-c116-4cb9-b33e-c8a5344a2337"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","created_at":"2023-04-24T05:22:32.392732+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"hour","symbol":"ETHUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"b7b756f8-e152-4435-8393-47fce471520b"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","created_at":"2023-04-24T05:22:32.472182+00:00","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","updated_at":null,"interval":"minute","symbol":"ETHUSDT","quote_asset":"USDT","asset_type":"Cryptocurrency","id":"fc63b9a0-72e0-4ff0-a8b2-360cbd00b7ab"}'
