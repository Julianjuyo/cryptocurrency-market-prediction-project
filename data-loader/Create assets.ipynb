# %%
import pandas as pd
import requests
import json

PROXIES = {
    
   'http': 'http://discproxy.virtual.uniandes.edu.co:443',
}

base_url = "http://172.24.100.128:5000/"
# base_url = "http://localhost:5000/"

# %%
# Method to make a POST request to the specified API endpoint with a JSON payload
def post_method(url_path, data_dict):
    print("POST request to: " + url_path)
    # Convert the dictionary to a JSON string using the `json` module
    json_payload = json.dumps(data_dict)

    print(json_payload)
    # try:
    # Send the POST request with the JSON payload
    response = requests.post(url_path, data=json_payload, proxies=PROXIES)

    # Check if the request was successful
    if response.status_code == requests.codes.created:
        # If successful, print the response content and convert it to a Pandas DataFrame
        print("created post status code: " + str(response.status_code))

        print(response.content)
        json_data = json.loads(response.content)
        df = pd.json_normalize(json_data)
        return df
    else:
        # If unsuccessful, print the response content
        print("post status code: "+str(response.status_code))
        print(response.content)

def create_exchange(base_url, data_dict):
    # Call the `post_mBTCod` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "exchanges")
    resp = post_method(base_url + "exchanges", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)
    
def create_asset(base_url,exchange_id, data_dict):
    # Call the `post_method` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "assets")
    resp = post_method(base_url + "exchanges/"+exchange_id+"/asset", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)

# %%
data ={
    "name": "binance"
}

# exchange = create_exchange(base_url,data)


# EXCHANGE_ID = exchange.iloc[0]['id']
EXCHANGE_ID = "e47be64c-3398-404f-878f-b5a5009a8f25"

# %%
array=[
    
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BTCUSDT",
    "base_asset": "BTC",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  },

  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
    
  },
  {
    "symbol": "BNBUSDT",
    "base_asset": "BNB",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  },

  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  },

    {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ETHUSDT",
    "base_asset": "ETH",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  }

]



for dict in array:
  create_asset(base_url,EXCHANGE_ID,dict)
# Out:
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","interval":"day","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:33.913178+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"4dcb33e9-ab8a-4619-8f48-540714218b15","symbol":"BTCUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","interval":"hour","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.020212+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"d942a40e-0b0c-44bb-a7f5-2233c7f5535a","symbol":"BTCUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BTCUSDT", "base_asset": "BTC", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BTC","interval":"minute","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.099408+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"6edf3a24-727b-47a9-b5fa-cd7d4ab47ae7","symbol":"BTCUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","interval":"day","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.178844+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"1f5b1c48-d1ae-4106-8584-e4493ca17d39","symbol":"BNBUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","interval":"hour","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.259120+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"171b0da9-caf5-4974-968c-a1061898f5a8","symbol":"BNBUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "BNBUSDT", "base_asset": "BNB", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"BNB","interval":"minute","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.338302+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"19f5e678-0c04-4991-9c67-abe3812f93c4","symbol":"BNBUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ADA","interval":"day","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.418538+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"f51c2eaf-b543-400f-8c12-cb6eb028ff67","symbol":"ADAUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ADA","interval":"hour","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.506731+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"96c1dd3a-cbfb-4787-a83b-8b1ea11e8ef0","symbol":"ADAUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ADA","interval":"minute","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.590865+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"bebec362-9358-40a1-a36b-860a8b658520","symbol":"ADAUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","interval":"day","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.670306+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"2b595929-6824-4776-be98-266610975a67","symbol":"ETHUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","interval":"hour","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.750743+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"8353e0ec-145d-42f4-83e8-34a274650119","symbol":"ETHUSDT"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/e47be64c-3398-404f-878f-b5a5009a8f25/asset
# {"symbol": "ETHUSDT", "base_asset": "ETH", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"base_asset":"ETH","interval":"minute","exchange_id":"e47be64c-3398-404f-878f-b5a5009a8f25","created_at":"2023-06-01T03:15:34.834588+00:00","updated_at":null,"quote_asset":"USDT","asset_type":"Cryptocurrency","id":"fe62183b-10ae-4ea2-a104-bb02d8928502","symbol":"ETHUSDT"}'
