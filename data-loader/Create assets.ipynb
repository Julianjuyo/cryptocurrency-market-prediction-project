# %%
import pandas as pd
import requests
import json

PROXIES = {
    
   'http': 'http://discproxy.virtual.uniandes.edu.co:443',
}

base_url = "http://172.24.100.128:5000/"
# base_url = "http://localhost:5000/"

# %%
# Method to make a POST request to the specified API endpoint with a JSON payload
def post_method(url_path, data_dict):
    print("POST request to: " + url_path)
    # Convert the dictionary to a JSON string using the `json` module
    json_payload = json.dumps(data_dict)

    print(json_payload)
    # try:
    # Send the POST request with the JSON payload
    response = requests.post(url_path, data=json_payload, proxies=PROXIES)

    # Check if the request was successful
    if response.status_code == requests.codes.created:
        # If successful, print the response content and convert it to a Pandas DataFrame
        print("created post status code: " + str(response.status_code))

        print(response.content)
        json_data = json.loads(response.content)
        df = pd.json_normalize(json_data)
        return df
    else:
        # If unsuccessful, print the response content
        print("post status code: "+str(response.status_code))
        print(response.content)

def create_exchange(base_url, data_dict):
    # Call the `post_mBTCod` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "exchanges")
    resp = post_method(base_url + "exchanges", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)
    
def create_asset(base_url,exchange_id, data_dict):
    # Call the `post_method` function with the appropriate URL and data dictionary
    print("Endpoint: " + base_url + "assets")
    resp = post_method(base_url + "exchanges/"+exchange_id+"/asset", data_dict)
    return resp
# post_method(base_url + "exchanges", data_dict)

# %%
data ={
    "name": "binance"
}

# exchange = create_exchange(base_url,data)


# EXCHANGE_ID = exchange.iloc[0]['id']
EXCHANGE_ID = "384d3f6f-c8ab-4552-969a-70fce9b1b242"

# %%
array=[
    
  # {
  #   "symbol": "BTCUSDT",
  #   "base_asset": "BTC",
  #   "quote_asset": "USDT",
  #   "interval": "day",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "BTCUSDT",
  #   "base_asset": "BTC",
  #   "quote_asset": "USDT",
  #   "interval": "hour",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "BTCUSDT",
  #   "base_asset": "BTC",
  #   "quote_asset": "USDT",
  #   "interval": "minute",
  #   "asset_type": "Cryptocurrency"
  # },

  # {
  #   "symbol": "BNBUSDT",
  #   "base_asset": "BNB",
  #   "quote_asset": "USDT",
  #   "interval": "day",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "BNBUSDT",
  #   "base_asset": "BNB",
  #   "quote_asset": "USDT",
  #   "interval": "hour",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "BNBUSDT",
  #   "base_asset": "BNB",
  #   "quote_asset": "USDT",
  #   "interval": "minute",
  #   "asset_type": "Cryptocurrency"
  # },

  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "day",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "hour",
    "asset_type": "Cryptocurrency"
  },
  {
    "symbol": "ADAUSDT",
    "base_asset": "ADA",
    "quote_asset": "USDT",
    "interval": "minute",
    "asset_type": "Cryptocurrency"
  }

  #   {
  #   "symbol": "ETHUSDT",
  #   "base_asset": "ETH",
  #   "quote_asset": "USDT",
  #   "interval": "day",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "ETHUSDT",
  #   "base_asset": "ETH",
  #   "quote_asset": "USDT",
  #   "interval": "hour",
  #   "asset_type": "Cryptocurrency"
  # },
  # {
  #   "symbol": "ETHUSDT",
  #   "base_asset": "ETH",
  #   "quote_asset": "USDT",
  #   "interval": "minute",
  #   "asset_type": "Cryptocurrency"
  # }
]


for dict in array:
  create_asset(base_url,EXCHANGE_ID,dict)
# Out:
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "day", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"updated_at":null,"interval":"day","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","base_asset":"ADA","created_at":"2023-04-25T05:57:01.124096+00:00","id":"c9313f95-9565-49a8-b96b-d96989f83820","quote_asset":"USDT","symbol":"ADAUSDT","asset_type":"Cryptocurrency"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "hour", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"updated_at":null,"interval":"hour","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","base_asset":"ADA","created_at":"2023-04-25T05:57:01.225262+00:00","id":"c16e4efa-e507-43ca-94d1-fc198b2c2d65","quote_asset":"USDT","symbol":"ADAUSDT","asset_type":"Cryptocurrency"}'
# Endpoint: http://172.24.100.128:5000/assets
# POST request to: http://172.24.100.128:5000/exchanges/384d3f6f-c8ab-4552-969a-70fce9b1b242/asset
# {"symbol": "ADAUSDT", "base_asset": "ADA", "quote_asset": "USDT", "interval": "minute", "asset_type": "Cryptocurrency"}
# created post status code: 201
# b'{"updated_at":null,"interval":"minute","exchange_id":"384d3f6f-c8ab-4552-969a-70fce9b1b242","base_asset":"ADA","created_at":"2023-04-25T05:57:01.306086+00:00","id":"105717ac-e8d5-4b1d-977d-6cc70d5d7ab8","quote_asset":"USDT","symbol":"ADAUSDT","asset_type":"Cryptocurrency"}'
